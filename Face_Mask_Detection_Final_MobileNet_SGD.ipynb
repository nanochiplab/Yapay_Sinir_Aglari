# %% [markdown]
# <a href="https://colab.research.google.com/github/nanochiplab/Yapay_Sinir_Aglari/blob/main/Face_Mask_Detection_Final_MobileNet_SGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.Gerekli Kütüphaneleri Yüklüyoruz
import os
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D # Added GlobalAveragePooling2D
from tensorflow.keras.models import Model

from sklearn.model_selection import train_test_split

# %%
# 2.	Veri Seti Yükleme

#Face Mask Detection Dataset’i yüklüyoruz....
#https://www.kaggle.com/datasets/omkargurav/face-mask-dataset

from google.colab import drive
drive.mount('/content/drive')

data_dir = '/content/drive/MyDrive/Yapay Sinir Ağları/Face Mask/data'  # Google Drive'daki klasör yolunu belirtin
os.chdir(data_dir)
# Out:
# Mounted at /content/drive

# %%
images = []
labels = []

# Tüm görüntüler için hedef size belirliyoruz...
target_size = (224, 224)  # Örnek boyutlandırma

for folder_name in os.listdir(data_dir):
    # Skip if it's not a directory (like model weight files)
    if not os.path.isdir(os.path.join(data_dir, folder_name)):
        continue

    label = folder_name
    folder_path = os.path.join(data_dir, folder_name)
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(folder_path, filename)

            # Read and resize the image
            image = cv2.imread(image_path)
            image = cv2.resize(image, target_size)  # target_size'a göre tekrar boyutlandırma

            images.append(image)
            labels.append(label)

images = np.array(images)
labels = np.array(labels)

print('Dosyalar başarıyla yüklendi......')
# Out:
# Dosyalar başarıyla yüklendi......

# %%
# 3.	Önceden Eğitilmiş (Pre-trained) Modellerin Hazırlanması

# Sınıflandırıcı olarak MobileNetV1'ı (pre-trained) kullanacağız....
# Base modeller indirildikten sonra 2 dense katmanı ve bir dropout katmanı ekledik...

from tensorflow.keras.applications import DenseNet121, MobileNet # Changed MobileNetV1 to MobileNet

# 4. Verilerimizi eğitim ve test kümelerine ayırdık..%80 eğitim ve %20 test verisi yapıyoruz...
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import categorical_crossentropy

# İsteğe bağlı olarak öğrenme oranını ayarlayabilirsiniz.0.001 değeriyle başladık...
#optimizer = Adam(learning_rate=0.001)
optimizer = SGD(learning_rate=0.001, momentum=0.7)  # İsteğe bağlı olarak öğrenme oranını ve momentumu ayarlayabilirsiniz.

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1)

# Modelin en iyi ağırlıklarını kaydetmek için ModelCheckpoint geri çağırmasını oluşturuyoruz......
checkpoint = ModelCheckpoint('best_model_weights_sgd.keras', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# %%
# Import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# Sınıf sayısını belirttik
# Örnek olarak 2 sınıf olduğunu varsayalım
num_classes = 2

# --- MobileNetV1 modeli ---
# MobileNet, özellikle mobil ve gömülü cihazlarda kullanılmak üzere tasarlanmış hafif bir evrişimli sinir ağı (CNN) mimarisidir. Hızlı ve verimli olmasıyla bilinir ve görüntü sınıflandırma, nesne algılama ve diğer bilgisayar görüşü görevlerinde yaygın olarak kullanılır.

# weights='imagenet'
# Bu parametre, modelin ImageNet veri seti üzerinde eğitilmiş ağırlıklarla başlatılacağını belirtir. ImageNet, milyonlarca görüntü içeren büyük bir veri setidir ve birçok farklı nesneyi içerir.
# ImageNet üzerinde eğitilmiş ağırlıklar, modelin birçok farklı nesneyi tanımayı öğrenmesini sağlar ve bu da transfer öğrenimi için faydalıdır.

#include_top=False
# Bu parametre, modelin en üstteki tamamen bağlı katmanlarını içermeyeceğini belirtir. Tamamen bağlı katmanlar, genellikle görüntü sınıflandırma gibi görevlerde kullanılır ve
# belirli bir sayıda sınıfa göre tahminler yapmak için kullanılır. include_top=False olarak ayarlandığında, model sadece evrişimli katmanları içerir ve bu da modelin farklı görevler için özelleştirilmesini sağlar.
base_model_mobilenet = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model_mobilenet.layers:
    layer.trainable = False

#Bu satır, MobileNet modelinin çıktı tensörünü x değişkenine atar. Bu, MobileNet modelinin çıktısını daha sonraki katmanlarda veya işlemlerde kullanabilmenizi sağlar.
x = base_model_mobilenet.output
x = GlobalAveragePooling2D()(x)        # MobileNet modelinin çıktısından elde edilen özellik haritasını (feature map) tek bir vektöre dönüştürür.
x = Dropout(0.5)(x)                    # Dropout katmanını uygulayarak, bir önceki katmanın çıktısındaki nöronların rastgele bir şekilde %50'sinin devre dışı bırakılmasını sağlar.

x = Dense(256, activation='relu')(x)   # Bir tam bağlantılı (Dense) katman ekler ve bu katmanda 256 nöron bulunur ve aktivasyon fonksiyonu olarak ReLU kullanır.
x = Dense(256, activation='relu')(x)
x = Dense(128, activation='relu')(x)
x = Dense(64, activation='relu')(x)

# Bu satırda da yine bir Dense katmanı kullanılıyor, ancak bu sefer farklı bir amacı var. Bu Dense katmanı, modelin son çıktısını üretmek için kullanılır.
# Dense(2, activation='softmax')
# 2: Bu, Dense katmanındaki nöron sayısını belirtir. Bu sayı, sınıflandırma probleminizdeki sınıf sayısıyla eşleşmelidir.
# Kodunuzda, iki sınıf olduğunu varsaydığımız için (örneğin, "maske", "maske yok"), bu değer 2 olarak ayarlanmıştır.
# activation='softmax': Bu, aktivasyon fonksiyonu olarak softmax kullanılacağını belirtir. Softmax fonksiyonu, çıktıyı olasılık dağılımına dönüştürür.
# Yani, her sınıf için bir olasılık değeri üretir ve bu olasılık değerlerinin toplamı 1'e eşit olur. Bu, çok sınıflı sınıflandırma problemlerinde yaygın olarak kullanılır.
predictions_mobilenet = Dense(2, activation='softmax')(x)

model_mobilenet = Model(inputs=base_model_mobilenet.input, outputs=predictions_mobilenet)
model_mobilenet.compile(optimizer=optimizer, loss=categorical_crossentropy, metrics=['accuracy'])

# LabelEncoder nesnesi oluşturuyoruz...
label_encoder = LabelEncoder()

# Fit the encoder to your labels and transform them
# LabelEncoder nesnesine eğitim verilerinizdeki benzersiz etiketleri öğrenmesini söyler. LabelEncoder, her benzersiz etikete bir sayısal etiket atar...
y_train_encoded = label_encoder.fit_transform(y_train)
# Bu adım, eğitim verilerimizdeki etiketleri öğrendiği sayısal etiketlere dönüştürür.
y_test_encoded = label_encoder.transform(y_test)

#****************************************************************************************************
# Hedef etiketleri kategorik veriye dönüştürmek için one-hot encoding kullanacağız...
from tensorflow.keras.utils import to_categorical  # Import to_categorical

#LabelEncoder ile sayısal hale getirilen etiketleri one-hot encoding kullanarak kategorik hale getireceğiz...
#Bu, kategoriler arasında sayısal bir sıralama ilişkisinin olmadığı durumlarda makine öğrenimi modellerinizin daha iyi performans göstermesine yardımcı olabilir.
y_train_encoded = to_categorical(y_train_encoded, num_classes=num_classes)
y_test_encoded = to_categorical(y_test_encoded, num_classes=num_classes)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# model eğitimi sırasında erken durdurma (early stopping) tekniğini uygulamak için bir EarlyStopping geriçağırımı (callback) oluşturacağız...
early_stopping = EarlyStopping(monitor='val_loss', patience=25)

# Model eğitimi sırasında veri arttırmayı kullanacağız...
# Veri arttırma parametrelerini ayarlayacağız

#Derin öğrenme modelleri, genellikle 0 ile 1 arasında ölçeklendirilmiş girdilerle daha iyi çalışır. Bu nedenle, görüntülerin piksel değerlerini bu aralığa ölçeklendirmek yaygın bir uygulamadır.
#rescale=1.0/255 parametresi, görüntülerin her piksel değerini 255'e bölerek 0 ile 1 arasında olacak şekilde ölçeklendirir. Bu işlem, modelin daha hızlı ve daha kararlı bir şekilde eğitilmesine yardımcı olabilir.
datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=10,         # -10 ila +10 derece arası döndürme yaılabilir...
    width_shift_range=0.1,     # width_shift_range=0.1 parametresi, görüntülerin genişliğinin %10'u kadar sağa veya sola kaydırılabileceğini belirtir.
    height_shift_range=0.1,    # Yani, her bir görüntü için rastgele bir kaydırma oranı seçilir ve görüntü bu oranda kaydırılır.
    shear_range=0.1,           # shear_range=0.1 parametresi, görüntülere uygulanacak kesme dönüşümünün yoğunluğunun maksimum 0.1 radyan olacağını belirtir.Yani, her bir görüntü için rastgele bir kesme açısı seçilir ve bu açı 0 ile 0.1 radyan arasında olur.
    zoom_range=0.1,            # görüntülerin rastgele olarak %10 oranında yakınlaştırılabileceğini veya uzaklaştırılabileceğini belirtir.
    horizontal_flip=True,      # Yatay çevirme, görüntünün dikey eksene göre ayna görüntüsü gibi çevrilmesi işlemidir. Veri arttırmada yatay çevirme kullanarak, modelin nesnelerin ters yönlerde görüntülenebileceği durumlara uyum sağlaması sağlanır.
    fill_mode='nearest'        # boşlukların en yakın pikselin değeriyle doldurulacağını belirtir.
)
# Bir görüntünün rotation_range=45 parametresiyle döndürüldüğünü ve fill_mode='nearest' olarak ayarlandığını düşünelim. Döndürme sonucunda görüntünün köşelerinde boşluklar oluşacaktır.
# Bu boşluklar, en yakın pikselin değeriyle doldurulacaktır.


# datagen.flow(X_train, y_train_encoded, batch_size=32): Bu kısım, eğitim verilerini ImageDataGenerator kullanarak veri arttırma ile besler.
# datagen nesnesi, eğitim verilerine rastgele dönüşümler uygulayarak modelin daha fazla veri görmesini ve aşırı öğrenmeyi önlemeye yardımcı olur. flow() metodu, eğitim verilerini batch'ler halinde üretir.
# epochs=100: Modelin eğitim verileri üzerinde kaç kez çalıştırılacağını belirtir. Her bir epoch, tüm eğitim verilerinin bir kez model tarafından işlenmesi anlamına gelir.
# validation_data=(X_test, y_test_encoded): Modelin performansını değerlendirmek için kullanılan doğrulama verilerini belirtir.
# Doğrulama verileri, eğitim sırasında modele gösterilmez ve modelin genelleme yeteneğini ölçmek için kullanılır.
# callbacks=[early_stopping, reduce_lr, checkpoint]: Eğitim sırasında kullanılacak geriçağırmaları (callbacks) belirtir.
# Geriçağırmalar, eğitim sürecini izlemek ve kontrol etmek için kullanılır. Kodunuzda, üç geriçağırımı kullanıyoruz:
# early_stopping: Modelin aşırı öğrenmesini önlemek için erken durdurma uygular.
# reduce_lr: Doğrulama kaybı belirli bir süre boyunca iyileşmezse öğrenme oranını azaltır.
# checkpoint: Modelin en iyi ağırlıklarını kaydeder.

history_mobilenet = model_mobilenet.fit(
    datagen.flow(X_train, y_train_encoded, batch_size=32), # Changed y_train to y_train_encoded
    epochs=100,
    validation_data=(X_test, y_test_encoded), # Changed y_test to y_test_encoded
    callbacks=[early_stopping, reduce_lr, checkpoint]  # ReduceLROnPlateau geri çağırmasını ekleme
)
# Veri arttırmayı eğitim verisine uygulayacağız...
datagen.fit(X_train)

# --- Modelleri değerlendirme aşamasına geldik ---
loss_mobilenet, accuracy_mobilenet = model_mobilenet.evaluate(X_test, y_test_encoded) # Use y_test_encoded

print("MobileNetV1 - Loss:", loss_mobilenet, "Accuracy:", accuracy_mobilenet)
#********************************************************************************************************
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.7025 - loss: 0.5724
# Epoch 1: val_accuracy improved from -inf to 0.62706, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 87s 379ms/step - accuracy: 0.7048 - loss: 0.5696 - val_accuracy: 0.6271 - val_loss: 0.6693 - learning_rate: 0.0010
# Epoch 2/100
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9351 - loss: 0.1893
# Epoch 2: val_accuracy improved from 0.62706 to 0.64356, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9352 - loss: 0.1890 - val_accuracy: 0.6436 - val_loss: 0.6735 - learning_rate: 0.0010
# Epoch 3/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9459 - loss: 0.1389
# Epoch 3: val_accuracy improved from 0.64356 to 0.66007, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9460 - loss: 0.1389 - val_accuracy: 0.6601 - val_loss: 0.6792 - learning_rate: 0.0010
# Epoch 4/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9639 - loss: 0.1017
# Epoch 4: val_accuracy improved from 0.66007 to 0.67459, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9639 - loss: 0.1018 - val_accuracy: 0.6746 - val_loss: 0.6912 - learning_rate: 0.0010
# Epoch 5/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9612 - loss: 0.1001
# Epoch 5: val_accuracy improved from 0.67459 to 0.67591, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9613 - loss: 0.0999 - val_accuracy: 0.6759 - val_loss: 0.6715 - learning_rate: 0.0010
# Epoch 6/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9658 - loss: 0.0865
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 6: val_accuracy improved from 0.67591 to 0.68119, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9659 - loss: 0.0865 - val_accuracy: 0.6812 - val_loss: 0.6709 - learning_rate: 0.0010
# Epoch 7/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9664 - loss: 0.0931
# Epoch 7: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9665 - loss: 0.0929 - val_accuracy: 0.6746 - val_loss: 0.6697 - learning_rate: 1.0000e-04
# Epoch 8/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9699 - loss: 0.0787
# Epoch 8: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9700 - loss: 0.0787 - val_accuracy: 0.6739 - val_loss: 0.6698 - learning_rate: 1.0000e-04
# Epoch 9/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9740 - loss: 0.0747
# Epoch 9: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9740 - loss: 0.0747 - val_accuracy: 0.6805 - val_loss: 0.6705 - learning_rate: 1.0000e-04
# Epoch 10/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9717 - loss: 0.0821
# Epoch 10: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9717 - loss: 0.0821 - val_accuracy: 0.6779 - val_loss: 0.6694 - learning_rate: 1.0000e-04
# Epoch 11/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9702 - loss: 0.0764
# Epoch 11: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9702 - loss: 0.0765 - val_accuracy: 0.6739 - val_loss: 0.6690 - learning_rate: 1.0000e-04
# Epoch 12/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9720 - loss: 0.0861
# Epoch 12: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9720 - loss: 0.0861 - val_accuracy: 0.6759 - val_loss: 0.6679 - learning_rate: 1.0000e-04
# Epoch 13/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9714 - loss: 0.0715
# Epoch 13: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9714 - loss: 0.0715 - val_accuracy: 0.6792 - val_loss: 0.6681 - learning_rate: 1.0000e-04
# Epoch 14/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9744 - loss: 0.0722
# Epoch 14: val_accuracy did not improve from 0.68119
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 294ms/step - accuracy: 0.9744 - loss: 0.0722 - val_accuracy: 0.6792 - val_loss: 0.6680 - learning_rate: 1.0000e-04
# Epoch 15/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9717 - loss: 0.0797
# Epoch 15: val_accuracy improved from 0.68119 to 0.68251, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9717 - loss: 0.0798 - val_accuracy: 0.6825 - val_loss: 0.6675 - learning_rate: 1.0000e-04
# Epoch 16/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9706 - loss: 0.0822
# Epoch 16: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9706 - loss: 0.0822 - val_accuracy: 0.6792 - val_loss: 0.6664 - learning_rate: 1.0000e-04
# Epoch 17/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9723 - loss: 0.0714
# Epoch 17: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9723 - loss: 0.0714 - val_accuracy: 0.6812 - val_loss: 0.6665 - learning_rate: 1.0000e-04
# Epoch 18/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9742 - loss: 0.0796
# Epoch 18: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9742 - loss: 0.0795 - val_accuracy: 0.6805 - val_loss: 0.6666 - learning_rate: 1.0000e-04
# Epoch 19/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9705 - loss: 0.0748
# Epoch 19: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9706 - loss: 0.0748 - val_accuracy: 0.6746 - val_loss: 0.6673 - learning_rate: 1.0000e-04
# Epoch 20/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9707 - loss: 0.0772
# Epoch 20: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9707 - loss: 0.0773 - val_accuracy: 0.6825 - val_loss: 0.6647 - learning_rate: 1.0000e-04
# Epoch 21/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9750 - loss: 0.0715
# Epoch 21: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9749 - loss: 0.0716 - val_accuracy: 0.6805 - val_loss: 0.6654 - learning_rate: 1.0000e-04
# Epoch 22/100
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9724 - loss: 0.0775
# Epoch 22: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9724 - loss: 0.0775 - val_accuracy: 0.6772 - val_loss: 0.6673 - learning_rate: 1.0000e-04
# Epoch 23/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9716 - loss: 0.0714
# Epoch 23: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 295ms/step - accuracy: 0.9716 - loss: 0.0714 - val_accuracy: 0.6766 - val_loss: 0.6669 - learning_rate: 1.0000e-04
# Epoch 24/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9743 - loss: 0.0735
# Epoch 24: val_accuracy did not improve from 0.68251
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9743 - loss: 0.0735 - val_accuracy: 0.6818 - val_loss: 0.6652 - learning_rate: 1.0000e-04
# Epoch 25/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9748 - loss: 0.0794
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 25: val_accuracy improved from 0.68251 to 0.68647, saving model to best_model_weights_sgd.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9748 - loss: 0.0794 - val_accuracy: 0.6865 - val_loss: 0.6649 - learning_rate: 1.0000e-04
# Epoch 26/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9748 - loss: 0.0743
# Epoch 26: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9748 - loss: 0.0742 - val_accuracy: 0.6851 - val_loss: 0.6646 - learning_rate: 1.0000e-05
# Epoch 27/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9721 - loss: 0.0750
# Epoch 27: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9721 - loss: 0.0751 - val_accuracy: 0.6825 - val_loss: 0.6643 - learning_rate: 1.0000e-05
# Epoch 28/100
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9719 - loss: 0.0737
# Epoch 28: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9719 - loss: 0.0736 - val_accuracy: 0.6818 - val_loss: 0.6643 - learning_rate: 1.0000e-05
# Epoch 29/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9730 - loss: 0.0708
# Epoch 29: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9730 - loss: 0.0709 - val_accuracy: 0.6825 - val_loss: 0.6642 - learning_rate: 1.0000e-05
# Epoch 30/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9734 - loss: 0.0654
# Epoch 30: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9734 - loss: 0.0655 - val_accuracy: 0.6825 - val_loss: 0.6642 - learning_rate: 1.0000e-05
# Epoch 31/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9724 - loss: 0.0779
# Epoch 31: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9724 - loss: 0.0778 - val_accuracy: 0.6832 - val_loss: 0.6643 - learning_rate: 1.0000e-05
# Epoch 32/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9750 - loss: 0.0679
# Epoch 32: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9750 - loss: 0.0679 - val_accuracy: 0.6832 - val_loss: 0.6643 - learning_rate: 1.0000e-05
# Epoch 33/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9680 - loss: 0.0774
# Epoch 33: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9681 - loss: 0.0774 - val_accuracy: 0.6825 - val_loss: 0.6642 - learning_rate: 1.0000e-05
# Epoch 34/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9762 - loss: 0.0676
# Epoch 34: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9763 - loss: 0.0676 - val_accuracy: 0.6832 - val_loss: 0.6644 - learning_rate: 1.0000e-05
# Epoch 35/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9746 - loss: 0.0702
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 35: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9746 - loss: 0.0702 - val_accuracy: 0.6845 - val_loss: 0.6643 - learning_rate: 1.0000e-05
# Epoch 36/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9725 - loss: 0.0769
# Epoch 36: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9726 - loss: 0.0769 - val_accuracy: 0.6845 - val_loss: 0.6643 - learning_rate: 1.0000e-06
# Epoch 37/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9712 - loss: 0.0750
# Epoch 37: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9712 - loss: 0.0749 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-06
# Epoch 38/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9724 - loss: 0.0778
# Epoch 38: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9724 - loss: 0.0776 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-06
# Epoch 39/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9748 - loss: 0.0776
# Epoch 39: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 292ms/step - accuracy: 0.9748 - loss: 0.0775 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-06
# Epoch 40/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9771 - loss: 0.0698
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 40: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 82s 292ms/step - accuracy: 0.9771 - loss: 0.0698 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-06
# Epoch 41/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9724 - loss: 0.0734
# Epoch 41: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9724 - loss: 0.0734 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-07
# Epoch 42/100
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9736 - loss: 0.0751
# Epoch 42: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 293ms/step - accuracy: 0.9736 - loss: 0.0750 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-07
# Epoch 43/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9722 - loss: 0.0692
# Epoch 43: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9722 - loss: 0.0693 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-07
# Epoch 44/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9696 - loss: 0.0805
# Epoch 44: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9696 - loss: 0.0805 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-07
# Epoch 45/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.9709 - loss: 0.0760
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
#
# Epoch 45: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9709 - loss: 0.0760 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-07
# Epoch 46/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9738 - loss: 0.0671
# Epoch 46: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 291ms/step - accuracy: 0.9738 - loss: 0.0672 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-08
# Epoch 47/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9765 - loss: 0.0651
# Epoch 47: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9764 - loss: 0.0654 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-08
# Epoch 48/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9766 - loss: 0.0718
# Epoch 48: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9766 - loss: 0.0717 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-08
# Epoch 49/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9743 - loss: 0.0705
# Epoch 49: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9742 - loss: 0.0706 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-08
# Epoch 50/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9717 - loss: 0.0755
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
#
# Epoch 50: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9716 - loss: 0.0755 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-08
# Epoch 51/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9745 - loss: 0.0702
# Epoch 51: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9745 - loss: 0.0703 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-09
# Epoch 52/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9716 - loss: 0.0799
# Epoch 52: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.9716 - loss: 0.0798 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-09
# Epoch 53/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9707 - loss: 0.0777
# Epoch 53: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.9707 - loss: 0.0778 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-09
# Epoch 54/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9743 - loss: 0.0636
# Epoch 54: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 58s 292ms/step - accuracy: 0.9742 - loss: 0.0639 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-09
# Epoch 55/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.9716 - loss: 0.0821
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
#
# Epoch 55: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.9715 - loss: 0.0821 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-09
# Epoch 56/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9816 - loss: 0.0635
# Epoch 56: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.9815 - loss: 0.0636 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-10
# Epoch 57/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.9743 - loss: 0.0694
# Epoch 57: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 290ms/step - accuracy: 0.9742 - loss: 0.0695 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-10
# Epoch 58/100
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9756 - loss: 0.0717
# Epoch 58: val_accuracy did not improve from 0.68647
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 57s 291ms/step - accuracy: 0.9756 - loss: 0.0718 - val_accuracy: 0.6845 - val_loss: 0.6644 - learning_rate: 1.0000e-10
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6747 - loss: 0.6544
# MobileNetV1 - Loss: 0.664386510848999 Accuracy: 0.6844884753227234

# %%
import matplotlib.pyplot as plt

#Her epok sonunda eğitim kaybı (loss) ve doğruluğu (accuracy) ile validasyon kaybı ve doğruluğunu kaydedip ve eğriyi çizdiriyoruz...
# Eğitim geçmişini kaydediyoruz...
loss = history_mobilenet.history['loss']
accuracy = history_mobilenet.history['accuracy']
val_loss = history_mobilenet.history['val_loss']
val_accuracy = history_mobilenet.history['val_accuracy']


epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Eğitim Kaybı')
plt.plot(epochs, val_loss, 'b', label='Validasyon Kaybı')
plt.title('Eğitim ve Validasyon Kaybı')
plt.xlabel('Epoklar')
plt.ylabel('Kayıp')
plt.legend()
plt.show()

plt.plot(epochs, accuracy, 'bo', label='Eğitim Doğruluğu')
plt.plot(epochs, val_accuracy, 'b', label='Validasyon Doğruluğu')
plt.title('Eğitim ve Validasyon Doğruluğu')
plt.xlabel('Epoklar')
plt.ylabel('Doğruluk')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# En iyi ağırlıkları yükleyeceğiz
model_mobilenet.load_weights('best_model_weights_sgd.keras')

# Fit the encoder to your original labels (if not already done)
label_encoder.fit(labels)  # 'labels' is your original label array

# Transform y_test to numerical labels
y_test_numeric = label_encoder.transform(y_test)
#*************************************************************

# Tahminleri olasılıklara dönüştürün
#ROC eğrisi veya AUC gibi metrikleri hesaplamak istiyorsak, genellikle pozitif sınıfın olasılıklarına ([:, 1] çıktısına) ihtiyaç duyacağız
#Bu durumda, y_pred_probs = model_mobilenet.predict(X_test)[:, 1] kodunu kullanmamız gerekiyor....
y_pred_probs = model_mobilenet.predict(X_test)[:, 1]

# ROC eğrisi ve AUC değerini hesaplayın
fpr, tpr, thresholds = roc_curve(y_test_numeric, y_pred_probs)  # Use y_test_numeric here
roc_auc = auc(fpr, tpr)


# ROC eğrisi ve AUC değerini hesaplayın
#fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
#roc_auc = auc(fpr, tpr)

# ROC eğrisini çizdirin
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC eğrisi (alan = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Yanlış Pozitif Oranı')
plt.ylabel('Doğru Pozitif Oranı')
plt.title('ROC Eğrisi')
plt.legend(loc="lower right")
plt.show()

# AUC değerini yazdırın
print('AUC:', roc_auc)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step
# AUC: 0.7459729892857268

# %%
# Tahminleri sınıflara dönüştürün
y_pred = np.argmax(model_mobilenet.predict(X_test), axis=1)

# Use LabelEncoder to transform y_test to numerical labels before calculating the confusion matrix
y_test_numeric = label_encoder.transform(y_test)

# Confusion Matrix'i hesaplayın ve yazdırın
cm = confusion_matrix(y_test_numeric, y_pred)  # Use y_test_numeric here
print('Confusion Matrix:\n', cm)

# Accuracy, Precision, Recall, Specificity ve F1-score'u hesaplayın ve yazdırın
accuracy = accuracy_score(y_test_numeric, y_pred)  # Use y_test_numeric here
precision = precision_score(y_test_numeric, y_pred)  # Use y_test_numeric here
recall = recall_score(y_test_numeric, y_pred)  # Use y_test_numeric here
specificity = cm[0, 0] / (cm[0, 0] + cm[0, 1])  # TN / (TN + FP)
f1 = f1_score(y_test_numeric, y_pred)  # Use y_test_numeric here

# Confusion matrix'i çizdiriyoruz..
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Tahmin Edilen Etiket")
plt.ylabel("Gerçek Etiket")
plt.show()

print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('Specificity:', specificity)
print('F1-score:', f1)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Confusion Matrix:
#  [[493 241]
#  [234 547]]
# Accuracy: 0.6864686468646864
# Precision: 0.6941624365482234
# Recall: 0.7003841229193342
# Specificity: 0.6716621253405994
# F1-score: 0.6972594008922881
